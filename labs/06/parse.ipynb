# %% [markdown]
# ### Lab06
# Please extend and reuse the code snippet such that the following details can be extracted from the CSV file.
#
# 1.	Extract all order numbers from the text.
# 2.	Extract all product codes.
# 3.	Extract all prices.
# 4.	Extract all order dates.
# 5.	Find all orders for products priced over $500. (You are allowed to use Python to filter the list.)
# 6.	Change the date format to DD/MM/YYYY. (Note the re.sub() method)
# 7.	Find all orders with the highest number of ordered items.
# 8.	Find the cheapest order(s). (You may want to use Python's min() method.)

# %%
import re 

def main():
    
    csv = read_csv()
    print("1. Order Numbers:", order_numbers(csv))
    print("2. Product Codes:", product_codes(csv))
    print("3. Prices:", prices(csv))
    print("4. Order Dates:", order_dates(csv))
    print("5. ", end="")
    over_500(csv)
    print("6. Reformatted Dates: ", date_format(csv))
    print("7. Most Items Ordered: ", most_items(csv))
    print("8. Cheapest Order(s): ", cheapest_order(csv))
    
    
def read_csv():
    #Read orders.csv and store it in a String
    with open('./csv/orders.csv') as f_in:
        text = f_in.read()
    
    return text

def order_numbers(csv):
    #RegEx for all order numbers #Format -> 913D6853-D43D-7847-31B3-2BBD8B67318E -> (Hex) 8x - 4x - 4x - 4x - 12x
    regex_order_numbers = r"[A-F0-9]{8}-[A-F0-9]{4}-[A-F0-9]{4}-[A-F0-9]{4}-[A-F0-9]{12}"
    order_numbers = re.findall(regex_order_numbers, csv)
    # print("Order Numbers:", order_numbers)
    return order_numbers 

def product_codes(csv):
    #RegEx for all product_codes
    #Format -> CGO15OKS6VJ -> 11x
    regex_product_codes = r"[A-Z0-9]{11}"
    product_codes = re.findall(regex_product_codes, csv)
    # print("Product Codes:", product_codes)
    return product_codes

def prices(csv):
    #RegEx for all prices
    #Format -> $902.53 -> $ 1x+ . xx
    regex_prices = r"\$\d+\.\d{2}"
    prices = re.findall(regex_prices, csv)
    # print("Prices:", prices)
    return prices

def order_dates(csv):
    #RegEx for all order dates
    #Format -> 01/30/2025 -> MM/DD/YYYY // xx / xx / xxxx
    regex_order_dates = r"\d{2}/\d{2}/\d{4}"
    order_dates = re.findall(regex_order_dates, csv)
    # print("Order Dates:", order_dates)
    return order_dates

def date_format(csv):
    #Reformats the date to DD/MM/YYYY instead of MM/DD/YYYY
    date = order_dates(csv)
    formatted_date = []
    
    for d in date:
        mm, dd, yyyy = d.split("/")
        formatted_date.append(f"{dd}/{mm}/{yyyy}")

    return formatted_date

def over_500(csv):
    #Find all orders for products priced over $500
    over_500_regex = r"^(.*),\$(\d+\.\d{2}),.*$"
    over_500 = [
        match.group(0) #Entire .csv line
        for match in re.finditer(over_500_regex, csv, flags=re.MULTILINE)
        if float(match.group(2)) > 500 #Check price (group 2)
    ]
    print("All Orders over $500: ", over_500)

def most_items(csv):
    #Find all Orders with the most Items 
    regex_items = r"^(.*?),\$(\d+\.\d{2}),(\d+),.*$"
    
    matches = list(re.finditer(regex_items, csv, flags=re.MULTILINE))
    item_counts = [int(m.group(3)) for m in matches]
    max_items = max(item_counts)

    most_items_orders = [
        m.group(0)
        for m in matches
        if int(m.group(3)) == max_items
    ]

    return most_items_orders


def cheapest_order(csv):
    #Find the cheapest order
    prices_raw = prices(csv)
    float_prices = [float(p.replace("$", "")) for p in prices_raw]
    price_min = min(float_prices)
    price_min_str = f"${price_min:.2f}"
    
    cheapest_regex = fr"^.*{re.escape(price_min_str)}.*$"
    cheapest_orders = [
        m.group(0)
        for m in re.finditer(cheapest_regex, csv, flags=re.MULTILINE)
    ]
        
    return cheapest_orders


if __name__ == '__main__':
    main()
# Out:
# 1. Order Numbers: ['913D6853-D43D-7847-31B3-2BBD8B67318E', '38139EAB-D7B8-7A66-2283-57136C174506', 'C994DE2B-9E23-B690-9854-91D7CB16CD81', '494166EE-43B1-ED00-576C-A5344A6A2695', '6EB66922-DC64-1865-BA11-8391D91481D5', '056B39A5-8E91-1543-4EC7-A686B4967C6C', '75E0D2B7-CCE8-20A7-68BB-2EAB73599AC9', '69899781-1889-9979-4785-1CF8DC64F606', 'F459BA97-4EA3-4724-34A9-267E57CBF533', '80B3E838-9416-082B-3594-BB6B86DAE874', 'D4443D3E-9EA9-5542-1C46-531E1D8979B3', '14E23DC5-E681-8173-B64F-78458840B608', 'D6636970-8BEB-9A28-356F-7B56DACEE531', '21ACE585-8D26-E365-29A1-C63E1E556FEA', '02930613-6D6B-5F97-C945-126626E0D6C0', '325DEF43-6321-E702-5278-1BC41116E623', '94894E91-1364-4897-53DB-4C35F8DE4B11', 'C0E8AE38-CCE9-8E99-ED23-C449D2A747FE', 'E604E618-FA56-83E8-3A11-881220EA5656', '5BDA4B85-64FB-4F99-71BC-CB101A5C51F7', 'D65E2D39-9299-B3D0-74BB-1BD762E59699', 'B7E1DBCD-D216-AA84-724E-5D8C4818D3A4', '466F78DC-C468-37A3-02F1-C0D84FD82C3B', 'CADB9B36-D5B0-7745-9ADA-8BAC1C0E5B1D', '5064DB58-EA45-388F-C3DA-24D952D78CC6', 'DECC9E21-A15A-8FD9-37D6-EF4A148294BF', '9979E439-F489-7872-572C-99BFE129B231', 'C7274D76-EB94-E049-A64D-A8C45AE3830A', '937B2801-CD82-1735-68A1-661AABE812A9', '5E99C449-50E7-7ED6-7B5B-D03EBBA17CEE', '691924C6-77E3-B16E-DD52-8ADDEAE6E491', 'E52CC82B-02C4-B7AE-3693-B9BC2DF76F3C', '431F7D2D-555E-6904-648E-D247221BD535', '8D47B8AB-1223-9666-53C5-3DB5E011B364', 'AD00CC84-9B69-7D1A-9F02-E224C2DB999E', '6DAB2938-5EF9-31B7-37C2-B7C61F70E977', '57BF7372-5634-87FD-3562-CCEE968AE18A', '9AD27A64-5B14-3EA2-6280-24D6FB2C7674', '1C6AEF1D-E0D7-4489-9672-E65B5B8A4392', '4C731F95-5721-CDC7-CBB6-7A9A5723CE82', '52779E92-A4A2-DAD0-B8CB-38ABB9823B82', '1E149108-8A1F-28A5-55CD-DEBA49ABE889', 'AD1E48EB-CC56-8B5F-443D-69D6EDEC181E', 'B6D4D6E8-E0C9-F4B3-59AD-EE24DCEFE4CE', '61345C9F-B062-22A7-1B67-9707529E342A', '2782CE19-85A6-F38D-198C-5BD2CEC2149B', '647E372C-1DD2-B087-DB77-A7FD538C743A', '74024862-69E7-F3DE-F3F7-8442249D43E9', 'BC2BDD57-62E5-3285-52CA-E1E2EF5A5A8E', 'A73DB3D0-7C28-E879-A8BC-AD750AB0CBEF', '9C755B76-9E14-D53A-6648-B1DC87A6419D', 'BE95A84C-E496-29E3-2815-AD70C563F0AD', '2D3B985C-33B4-CB40-4B98-553CDAA47715', '3132B5E2-FB12-6A3C-5D3C-3A68752378C7', '947832EB-C510-4A8E-482C-CF2278243A5B', '72D23817-210D-289E-9798-B6F74F927795', '58C521E5-270B-D323-66A7-219AA1C23BC3', '5BD9AC25-2392-9F7E-E4A5-C79344C70C72', '4327C7A2-C848-B4BE-5851-62815A7FE984', '7DB6CB40-3915-25E1-4839-0DEC7C7CA2DC', 'F7B8C683-9DC9-AEB2-A962-67CB94E9DCD4', '788C6241-9E74-2F16-1EAC-7EAFEA97848C', '2BD16188-4345-3785-BD15-A95782E32DD4', '6FF65E38-5FC0-7436-E0D2-AEB082ACA3FA', 'D4C2365B-6DEC-404A-8005-64783CE9A27E', '3A87633D-F9AC-8A65-937F-E84C605FB946', '86971494-808C-D6D0-BFA1-04846D123A62', '754A965D-B45E-B949-6658-D575BCF78DDE', 'A2B64252-D584-3263-2091-92933529AD7A', '4557E7B3-1DAE-2D85-39D3-C9CC6858719D', '697C4C2E-4F17-B46E-91B8-D7105EA3EA02', '74D7135E-B748-5FD3-EE10-0279B289A769', '6EC5B392-A87E-BAA4-C8A3-E72D7196567C', '1403F44D-EC39-1796-3450-97A8D97F231E', '6361512A-B559-1BA7-72B4-100DA3BA4DC7', '14DE115B-52C3-27C5-7275-35D1EC923B23', '3E3214CA-9EB2-A66F-1C73-6A5A755DC496', '08356C7C-9D4B-8E26-5554-D63EA14A4C5D', 'BE6A1B2E-7634-A255-73D3-63E3B8FAE056', 'DB5EEB73-DA58-4C7D-81CA-5147595A7CD5', 'DE3C4D2B-72DA-C27A-4437-09F1CA5E1D0A', 'D1C3FD36-F754-1675-4D27-840F13CCE777', '980E7C0E-2D6B-6B4A-1BB7-487D8754AC9D', '25790782-2A3B-733E-8B18-5875BCEF49E6', '52719A32-23C5-566C-BD69-B85CD1BFE843', 'B52BB1A3-55B2-ABB2-7008-1279D45E6AF9', '0B995A66-6669-38E9-B531-4DFBB1650279', '46414FA8-2753-2123-949D-8333E1783738', 'A49449D1-29DE-D7C5-42B1-D56381F8158B', 'A4A362B3-80AE-4544-ABD2-A3C7743BD136', 'BE1D3D9F-6C61-784A-B3C1-D97A0DC20C11', '4C1A5955-222F-412A-ACCA-241DD5A0566E', 'BD87DEA9-598C-C36F-634E-8282AE9B7CE2', 'E64EAECE-978C-4B56-A967-05A2F92C6272', 'C8EE58CD-E0ED-73CF-852C-CEC6A91C345C', 'D163A0A6-4111-22C5-3EF0-432925A85491', '4E6DD357-438E-C5B2-79A9-3A8BE9C84A9C', 'E4A9A2E1-52DA-24AA-7924-AD44C5F25663', 'A8FC5228-0F9F-67D5-6AC5-55BB39072EA6', 'BB79E955-8BC9-C533-B ...
# 2. Product Codes: ['KPT62OVE7BS', '2BBD8B67318', 'QNI12WUN3CD', '57136C17450', 'WCY48VND3EX', '91D7CB16CD8', 'XEC54CXI3AG', 'A5344A6A269', 'IMF54TDN1JR', '8391D91481D', 'VOL14UQX1XD', 'A686B4967C6', 'CTS23VKM0HQ', '2EAB73599AC', 'QET08DJU7PM', '1CF8DC64F60', 'COO14PMT4VM', '267E57CBF53', 'NHU70QWB4NF', 'BB6B86DAE87', 'TPE36PAV9CL', '531E1D8979B', 'CML33NQH2TB', '78458840B60', 'TCE72BHG5ZH', '7B56DACEE53', 'NRO32NPJ6ET', 'C63E1E556FE', 'DTW46KFI1VQ', '126626E0D6C', 'TBB84ZAJ8AF', '1BC41116E62', 'KXW13GBV6YU', '4C35F8DE4B1', 'VRY59HYB1LC', 'C449D2A747F', 'QBT75SEU9EV', '881220EA565', 'EYQ86OKC0US', 'CB101A5C51F', 'ZLO83MHB3EH', '1BD762E5969', 'DAK65QXK8ZJ', '5D8C4818D3A', 'FUK10FST9DM', 'C0D84FD82C3', 'POO81PLQ3MA', '8BAC1C0E5B1', 'GJX12SNP8CC', '24D952D78CC', 'PGG42TKG2QW', 'EF4A148294B', 'BRF08UXC4EZ', '99BFE129B23', 'OJD81MVD2GC', 'A8C45AE3830', 'SRD14VWO7RT', '661AABE812A', 'FLZ43DQE8ZF', 'D03EBBA17CE', 'VXP83JCC6DR', '8ADDEAE6E49', 'FMI50YAK5KP', 'B9BC2DF76F3', 'UZQ24QCU5NV', 'D247221BD53', 'JIG95NDS6BL', '3DB5E011B36', 'BOR06IGS2CR', 'E224C2DB999', 'NYT88BTL9ML', 'B7C61F70E97', 'YNF86MAN8JV', 'CCEE968AE18', 'VTI45GCU3EC', '24D6FB2C767', 'CYW04QOY9QH', 'E65B5B8A439', 'LSL72LFN9PY', '7A9A5723CE8', 'BVF33WBS2NJ', '38ABB9823B8', 'ICC48AKQ2JE', 'DEBA49ABE88', 'YGQ04QHR1CK', '69D6EDEC181', 'HDH68PBA2CK', 'EE24DCEFE4C', 'VEQ11XOM8CJ', '9707529E342', 'QTT37GSZ9IW', '5BD2CEC2149', 'DTB78VKF2LT', 'A7FD538C743', 'ZHP55SRU4LY', '8442249D43E', 'FIK61MIS2BC', 'E1E2EF5A5A8', 'MER44UNH8GL', 'AD750AB0CBE', 'HPV39TVQ1MP', 'B1DC87A6419', 'HON34JEH8QD', 'AD70C563F0A', 'MLP92NUV7QC', '553CDAA4771', 'OFU18EMD2TT', '3A68752378C', 'XOT69SOL6OM', 'CF2278243A5', 'VUW62VIK9PY', 'B6F74F92779', 'VED84HOY4XU', '219AA1C23BC', 'APB40BQM0KQ', 'C79344C70C7', 'PHT27ODJ8NN', '62815A7FE98', 'SPB68BVH5NF', '0DEC7C7CA2D', 'GYU48AHY0SR', '67CB94E9DCD', 'BSN73TDC1ID', '7EAFEA97848', 'LIC86LIB8ZQ', 'A95782E32DD', 'RBI93QCQ5EX', 'AEB082ACA3F', 'FGM39TVW5GY', '64783CE9A27', 'BGN26LMQ8SX', 'E84C605FB94', 'WPK49NYD4FC', '04846D123A6', 'NAC58SWB5BS', 'D575BCF78DD', 'DBM78XUI4LG', '92933529AD7', 'MGO51MTB8TM', 'C9CC6858719', 'NAO45UBF6TW', 'D7105EA3EA0', 'RPI13DCK5RO', '0279B289A76', 'UUD61FHK1VY', 'E72D7196567', 'LAI11TMV6AH', '97A8D97F231', 'LYQ97TXJ6VO', '100DA3BA4DC', 'FQM63HMQ5WI', '35D1EC923B2', 'YGW97BTV3ZX', '6A5A755DC49', 'IYD77EII1CU', 'D63EA14A4C5', 'JLR61DIY9FF', '63E3B8FAE05', 'JEH76BZK6LW', '5147595A7CD', 'AUP87NKV8IE', '09F1CA5E1D0', 'AHM23IIH4YT', '840F13CCE77', 'CGO15OKS6VJ', '487D8754AC9', 'FGC41TQE8UM', '5875BCEF49E', 'OBR27NOC5KD', 'B85CD1BFE84', 'ZEW65FQV8DE', '1279D45E6AF', 'VNY17BRU7MB', '4DFBB165027', 'UED22VWI8FM', '8333E178373', 'KCP17OKT6WR', 'D56381F8158', 'YIR15DHQ6EU', 'A3C7743BD13', 'VFA34UJE5EQ', 'D97A0DC20C1', 'KPS15FQE5DG', '241DD5A0566', 'BMI35LOP7FX', '8282AE9B7CE', 'DFP91EYM5MD', '05A2F92C627', 'FDV51RUV6XV', 'CEC6A91C345', 'WNS87HPG9EE', '432925A8549', 'FPJ78RKE3ZX', '3A8BE9C84A9', 'TFZ54QAM5NR', 'AD44C5F2566', 'EBN63YUL5LT', '55BB39072EA', 'VVO15XLY7QW', '153459BFC2D']
# 3. Prices: ['$449.87', '$902.53', '$461.70', '$658.46', '$655.72', '$216.41', '$826.02', '$508.56', '$746.35', '$854.44', '$422.60', '$412.76', '$57.47', '$199.97', '$70.64', '$115.48', '$594.33', '$339.07', '$636.91', '$850.72', '$666.12', '$762.15', '$423.90', '$411.14', '$183.13', '$597.64', '$595.82', '$515.65', '$85.36', '$523.30', '$101.17', '$385.20', '$533.52', '$85.51', '$295.83', '$342.43', '$733.96', '$189.64', '$341.99', '$815.01', '$824.01', '$957.11', '$794.39', '$920.64', '$73.80', '$873.22', '$672.06', '$725.68', '$737.96', '$426.31', '$372.18', '$926.38', '$781.35', '$209.91', '$440.92', '$626.78', '$604.40', '$831.28', '$997.50', '$287.48', '$521.13', '$971.62', '$781.22', '$553.15', '$918.08', '$240.68', '$730.81', '$825.13', '$598.54', '$905.42', '$16.01', '$400.17', '$819.38', '$60.14', '$483.10', '$197.53', '$770.10', '$977.02', '$365.27', '$637.42', '$827.09', '$100.85', '$479.24', '$384.90', '$349.01', '$995.42', '$705.56', '$119.61', '$510.46', '$301.97', '$555.45', '$254.91', '$368.40', '$969.04', '$11.59', '$600.16', '$110.99', '$851.70', '$961.45', '$278.94']
# 4. Order Dates: ['03/13/2025', '07/05/2025', '08/05/2025', '01/30/2025', '04/04/2025', '02/16/2025', '08/12/2025', '04/08/2025', '03/28/2025', '08/29/2025', '03/09/2025', '02/19/2025', '07/21/2025', '06/17/2025', '05/25/2025', '01/16/2025', '05/15/2025', '08/14/2025', '06/01/2025', '02/28/2025', '02/13/2025', '09/24/2025', '08/13/2025', '06/12/2025', '07/21/2025', '05/15/2025', '01/10/2025', '09/04/2025', '07/29/2025', '05/15/2025', '02/20/2025', '02/16/2025', '03/07/2025', '01/20/2025', '08/24/2025', '06/09/2025', '07/09/2025', '04/05/2025', '04/14/2025', '07/12/2025', '06/23/2025', '01/11/2025', '08/27/2025', '06/24/2025', '09/05/2025', '07/10/2025', '06/12/2025', '07/08/2025', '05/22/2025', '08/14/2025', '02/19/2025', '06/24/2025', '07/27/2025', '09/17/2025', '04/01/2025', '07/01/2025', '02/15/2025', '03/10/2025', '08/06/2025', '08/24/2025', '03/12/2025', '03/20/2025', '01/29/2025', '07/05/2025', '09/06/2025', '06/16/2025', '08/10/2025', '01/12/2025', '01/02/2025', '08/30/2025', '08/12/2025', '08/15/2025', '09/24/2025', '09/21/2025', '06/12/2025', '03/15/2025', '07/20/2025', '06/27/2025', '09/08/2025', '06/05/2025', '02/03/2025', '04/27/2025', '06/30/2025', '09/23/2025', '01/31/2025', '06/11/2025', '08/21/2025', '08/01/2025', '06/08/2025', '01/15/2025', '07/30/2025', '01/08/2025', '08/10/2025', '09/05/2025', '08/27/2025', '01/13/2025', '09/21/2025', '05/04/2025', '05/17/2025', '09/24/2025']
# 5. All Orders over $500:  ['QNI12WUN3CD,38139EAB-D7B8-7A66-2283-57136C174506,$902.53,3,07/05/2025', 'XEC54CXI3AG,494166EE-43B1-ED00-576C-A5344A6A2695,$658.46,7,01/30/2025', 'IMF54TDN1JR,6EB66922-DC64-1865-BA11-8391D91481D5,$655.72,8,04/04/2025', 'CTS23VKM0HQ,75E0D2B7-CCE8-20A7-68BB-2EAB73599AC9,$826.02,2,08/12/2025', 'QET08DJU7PM,69899781-1889-9979-4785-1CF8DC64F606,$508.56,8,04/08/2025', 'COO14PMT4VM,F459BA97-4EA3-4724-34A9-267E57CBF533,$746.35,9,03/28/2025', 'NHU70QWB4NF,80B3E838-9416-082B-3594-BB6B86DAE874,$854.44,8,08/29/2025', 'KXW13GBV6YU,94894E91-1364-4897-53DB-4C35F8DE4B11,$594.33,7,05/15/2025', 'QBT75SEU9EV,E604E618-FA56-83E8-3A11-881220EA5656,$636.91,2,06/01/2025', 'EYQ86OKC0US,5BDA4B85-64FB-4F99-71BC-CB101A5C51F7,$850.72,3,02/28/2025', 'ZLO83MHB3EH,D65E2D39-9299-B3D0-74BB-1BD762E59699,$666.12,9,02/13/2025', 'DAK65QXK8ZJ,B7E1DBCD-D216-AA84-724E-5D8C4818D3A4,$762.15,4,09/24/2025', 'PGG42TKG2QW,DECC9E21-A15A-8FD9-37D6-EF4A148294BF,$597.64,2,05/15/2025', 'BRF08UXC4EZ,9979E439-F489-7872-572C-99BFE129B231,$595.82,10,01/10/2025', 'OJD81MVD2GC,C7274D76-EB94-E049-A64D-A8C45AE3830A,$515.65,3,09/04/2025', 'FLZ43DQE8ZF,5E99C449-50E7-7ED6-7B5B-D03EBBA17CEE,$523.30,7,05/15/2025', 'UZQ24QCU5NV,431F7D2D-555E-6904-648E-D247221BD535,$533.52,5,03/07/2025', 'YNF86MAN8JV,57BF7372-5634-87FD-3562-CCEE968AE18A,$733.96,5,07/09/2025', 'LSL72LFN9PY,4C731F95-5721-CDC7-CBB6-7A9A5723CE82,$815.01,3,07/12/2025', 'BVF33WBS2NJ,52779E92-A4A2-DAD0-B8CB-38ABB9823B82,$824.01,4,06/23/2025', 'ICC48AKQ2JE,1E149108-8A1F-28A5-55CD-DEBA49ABE889,$957.11,8,01/11/2025', 'YGQ04QHR1CK,AD1E48EB-CC56-8B5F-443D-69D6EDEC181E,$794.39,3,08/27/2025', 'HDH68PBA2CK,B6D4D6E8-E0C9-F4B3-59AD-EE24DCEFE4CE,$920.64,9,06/24/2025', 'QTT37GSZ9IW,2782CE19-85A6-F38D-198C-5BD2CEC2149B,$873.22,7,07/10/2025', 'DTB78VKF2LT,647E372C-1DD2-B087-DB77-A7FD538C743A,$672.06,8,06/12/2025', 'ZHP55SRU4LY,74024862-69E7-F3DE-F3F7-8442249D43E9,$725.68,8,07/08/2025', 'FIK61MIS2BC,BC2BDD57-62E5-3285-52CA-E1E2EF5A5A8E,$737.96,9,05/22/2025', 'HON34JEH8QD,BE95A84C-E496-29E3-2815-AD70C563F0AD,$926.38,8,06/24/2025', 'MLP92NUV7QC,2D3B985C-33B4-CB40-4B98-553CDAA47715,$781.35,6,07/27/2025', 'VUW62VIK9PY,72D23817-210D-289E-9798-B6F74F927795,$626.78,4,07/01/2025', 'VED84HOY4XU,58C521E5-270B-D323-66A7-219AA1C23BC3,$604.40,9,02/15/2025', 'APB40BQM0KQ,5BD9AC25-2392-9F7E-E4A5-C79344C70C72,$831.28,5,03/10/2025', 'PHT27ODJ8NN,4327C7A2-C848-B4BE-5851-62815A7FE984,$997.50,7,08/06/2025', 'GYU48AHY0SR,F7B8C683-9DC9-AEB2-A962-67CB94E9DCD4,$521.13,8,03/12/2025', 'BSN73TDC1ID,788C6241-9E74-2F16-1EAC-7EAFEA97848C,$971.62,8,03/20/2025', 'LIC86LIB8ZQ,2BD16188-4345-3785-BD15-A95782E32DD4,$781.22,6,01/29/2025', 'RBI93QCQ5EX,6FF65E38-5FC0-7436-E0D2-AEB082ACA3FA,$553.15,10,07/05/2025', 'FGM39TVW5GY,D4C2365B-6DEC-404A-8005-64783CE9A27E,$918.08,2,09/06/2025', 'WPK49NYD4FC,86971494-808C-D6D0-BFA1-04846D123A62,$730.81,1,08/10/2025', 'NAC58SWB5BS,754A965D-B45E-B949-6658-D575BCF78DDE,$825.13,6,01/12/2025', 'DBM78XUI4LG,A2B64252-D584-3263-2091-92933529AD7A,$598.54,8,01/02/2025', 'MGO51MTB8TM,4557E7B3-1DAE-2D85-39D3-C9CC6858719D,$905.42,3,08/30/2025', 'UUD61FHK1VY,6EC5B392-A87E-BAA4-C8A3-E72D7196567C,$819.38,8,09/24/2025', 'YGW97BTV3ZX,3E3214CA-9EB2-A66F-1C73-6A5A755DC496,$770.10,7,07/20/2025', 'IYD77EII1CU,08356C7C-9D4B-8E26-5554-D63EA14A4C5D,$977.02,9,06/27/2025', 'JEH76BZK6LW,DB5EEB73-DA58-4C7D-81CA-5147595A7CD5,$637.42,4,06/05/2025', 'AUP87NKV8IE,DE3C4D2B-72DA-C27A-4437-09F1CA5E1D0A,$827.09,5,02/03/2025', 'ZEW65FQV8DE,B52BB1A3-55B2-ABB2-7008-1279D45E6AF9,$995.42,4,06/11/2025', 'VNY17BRU7MB,0B995A66-6669-38E9-B531-4DFBB1650279,$705.56,4,08/21/2025', 'KCP17OKT6WR,A49449D1-29DE-D7C5-42B1-D56381F8158B,$510.46,10,06/08/2025', 'VFA34UJE5EQ,BE1D3D9F-6C61-784A-B3C1-D97A0DC20C11,$555.45,1,07/30/2025', 'DFP91EYM5MD,E64EAECE-978C-4B56-A967-05A2F92C6272,$969.04,5,09/05/2025', 'WNS87HPG9EE,D163A0A6-4111-22C5-3EF0-432925A85491,$600.16,4,01/13/2025', 'TFZ54QAM5NR,E4A9A2E1-52DA-24AA-7924-AD44C5F25663,$851.70,2,05/04/2025', 'EBN63YUL5LT,A8FC5228-0F9F-6 ...
# 6. Reformatted Dates:  ['13/03/2025', '05/07/2025', '05/08/2025', '30/01/2025', '04/04/2025', '16/02/2025', '12/08/2025', '08/04/2025', '28/03/2025', '29/08/2025', '09/03/2025', '19/02/2025', '21/07/2025', '17/06/2025', '25/05/2025', '16/01/2025', '15/05/2025', '14/08/2025', '01/06/2025', '28/02/2025', '13/02/2025', '24/09/2025', '13/08/2025', '12/06/2025', '21/07/2025', '15/05/2025', '10/01/2025', '04/09/2025', '29/07/2025', '15/05/2025', '20/02/2025', '16/02/2025', '07/03/2025', '20/01/2025', '24/08/2025', '09/06/2025', '09/07/2025', '05/04/2025', '14/04/2025', '12/07/2025', '23/06/2025', '11/01/2025', '27/08/2025', '24/06/2025', '05/09/2025', '10/07/2025', '12/06/2025', '08/07/2025', '22/05/2025', '14/08/2025', '19/02/2025', '24/06/2025', '27/07/2025', '17/09/2025', '01/04/2025', '01/07/2025', '15/02/2025', '10/03/2025', '06/08/2025', '24/08/2025', '12/03/2025', '20/03/2025', '29/01/2025', '05/07/2025', '06/09/2025', '16/06/2025', '10/08/2025', '12/01/2025', '02/01/2025', '30/08/2025', '12/08/2025', '15/08/2025', '24/09/2025', '21/09/2025', '12/06/2025', '15/03/2025', '20/07/2025', '27/06/2025', '08/09/2025', '05/06/2025', '03/02/2025', '27/04/2025', '30/06/2025', '23/09/2025', '31/01/2025', '11/06/2025', '21/08/2025', '01/08/2025', '08/06/2025', '15/01/2025', '30/07/2025', '08/01/2025', '10/08/2025', '05/09/2025', '27/08/2025', '13/01/2025', '21/09/2025', '04/05/2025', '17/05/2025', '24/09/2025']
# 7. Most Items Ordered:  ['POO81PLQ3MA,CADB9B36-D5B0-7745-9ADA-8BAC1C0E5B1D,$411.14,10,06/12/2025', 'BRF08UXC4EZ,9979E439-F489-7872-572C-99BFE129B231,$595.82,10,01/10/2025', 'SRD14VWO7RT,937B2801-CD82-1735-68A1-661AABE812A9,$85.36,10,07/29/2025', 'CYW04QOY9QH,1C6AEF1D-E0D7-4489-9672-E65B5B8A4392,$341.99,10,04/14/2025', 'RBI93QCQ5EX,6FF65E38-5FC0-7436-E0D2-AEB082ACA3FA,$553.15,10,07/05/2025', 'KCP17OKT6WR,A49449D1-29DE-D7C5-42B1-D56381F8158B,$510.46,10,06/08/2025']
# 8. Cheapest Order(s):  ['FDV51RUV6XV,C8EE58CD-E0ED-73CF-852C-CEC6A91C345C,$11.59,8,08/27/2025']
